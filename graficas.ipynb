# %%
import numpy as np
from main import comparar_curvas, comparar_curvas_pot

# %% [markdown]
# Comparar Curvas de Luz con parámetros (i,q, r1, r2, L2/L1)

# %% [markdown]
# ASAS 203113+0513.2

# %%
comparar_curvas(np.deg2rad(77.06),0.914,0.2,0.281,1.282, 0.52169, 203113)
# Out:
# Mejor t0 seleccionado: 4256.8389
# Numero de puntos experimentales= 401
# Promedio de magnitudes en fase 0.25: 3.28069740718842
# Promedio de magnitudes en fase 0.75: 3.2532130396261385
# Factor escalar = 3.2556557524367373
# Suma de errores cuadráticos normalizada: 0.010609750075823175

# %% [markdown]
# ASAS 011416+0426.4

# %%
comparar_curvas(np.deg2rad(88.323), 0.808 ,0.113, 0.081 ,0.299, 2.478, '011416')
# Out:
# Mejor t0 seleccionado: 2990.61861
# Numero de puntos experimentales= 359
# Promedio de magnitudes en fase 0.25: 0.6033786654434051
# Promedio de magnitudes en fase 0.75: 0.5906236041829919
# Factor escalar = 0.5955084368705397
# Suma de errores cuadráticos normalizada: 0.0004994831443661173

# %% [markdown]
# ASAS 010538-8003.7

# %%
comparar_curvas(np.deg2rad(80.4),1.003 ,0.135, 0.174, 0.444, 8.069406, '010538')
# Out:
# Mejor t0 seleccionado: 3898.86297
# Numero de puntos experimentales= 1059
# Promedio de magnitudes en fase 0.25: 0.924044993362654
# Promedio de magnitudes en fase 0.75: 0.9178308393204511
# Factor escalar = 0.9217682853760159
# Suma de errores cuadráticos normalizada: 0.0011279745459228563

# %% [markdown]
# ASAS 023631+1208.6

# %%
comparar_curvas(np.deg2rad(87.4), 0.839, 0.136 ,0.096, 0.471,3.604913, '023631')
# Out:
# Mejor t0 seleccionado: 3321.64007
# Numero de puntos experimentales= 325
# Promedio de magnitudes en fase 0.25: 1.2277685773317426
# Promedio de magnitudes en fase 0.75: 1.2417762108861847
# Factor escalar = 1.253523182603189
# Suma de errores cuadráticos normalizada: 0.010765195508950474

# %% [markdown]
# ASAS 085524-4411.3

# %%
comparar_curvas(np.deg2rad(86.4), 0.8772 ,0.092, 0.081, 0.751,7.040274, '085524')
# Out:
# Mejor t0 seleccionado: 1966.62021
# Numero de puntos experimentales= 841
# Promedio de magnitudes en fase 0.25: 1.04969757379739
# Promedio de magnitudes en fase 0.75: 1.039127855833206
# Factor escalar = 1.044412714815298
# Suma de errores cuadráticos normalizada: 0.0022007633425778694

# %% [markdown]
# ASAS 150145-5242.2

# %%
comparar_curvas(np.deg2rad(84.7), 1.002 ,0.136, 0.134, 0.981,5.976930, '150145')
# Out:
# Mejor t0 seleccionado: 4748.49545
# Numero de puntos experimentales= 731
# Promedio de magnitudes en fase 0.25: 1.4485211155788622
# Promedio de magnitudes en fase 0.75: 1.4556221860924032
# Factor escalar = 1.4506275961695967
# Suma de errores cuadráticos normalizada: 0.00111325724364622

# %% [markdown]
# ASAS 155259-6637.8

# %%
comparar_curvas(np.deg2rad(84.5), 1.214 ,0.094 ,0.145 ,2.211,5.744754, '155259')
# Out:
# Mejor t0 seleccionado: 3772.84385
# Numero de puntos experimentales= 564
# Promedio de magnitudes en fase 0.25: 2.4984712449433655
# Promedio de magnitudes en fase 0.75: 2.5098385963400176
# Factor escalar = 2.5048736860176977
# Suma de errores cuadráticos normalizada: 0.00795792310599334

# %% [markdown]
# ASAS 155358-5553.4

# %%
comparar_curvas(np.deg2rad(86.3), 1.043, 0.131, 0.143, 1.062, 5.691743, '155358')
# Out:
# Mejor t0 seleccionado: 3458.85022
# Numero de puntos experimentales= 542
# Promedio de magnitudes en fase 0.25: 1.412137569475455
# Promedio de magnitudes en fase 0.75: 1.4241980942817998
# Factor escalar = 1.418944424492694
# Suma de errores cuadráticos normalizada: 0.000781448440042154

# %% [markdown]
# ASAS 174626-1153.0

# %%
comparar_curvas(np.deg2rad(81.4), 1.21, 0.158, 0.209 ,1.433, 3.011055, '174626')
# Out:
# Mejor t0 seleccionado: 2862.66392
# Numero de puntos experimentales= 609
# Promedio de magnitudes en fase 0.25: 0.43895480389536157
# Promedio de magnitudes en fase 0.75: 0.45432510640283236
# Factor escalar = 0.4545433881705996
# Suma de errores cuadráticos normalizada: 0.00019934567411763248

# %% [markdown]
# ASAS 193044+1340.3

# %%
comparar_curvas(np.deg2rad(87.6), 0.930 ,0.161, 0.127, 0.559, 4.925489, '193044')
# Out:
# Mejor t0 seleccionado: 3657.55658
# Numero de puntos experimentales= 374
# Promedio de magnitudes en fase 0.25: 0.659628278906162
# Promedio de magnitudes en fase 0.75: 0.6520002859372391
# Factor escalar = 0.6558142824217006
# Suma de errores cuadráticos normalizada: 0.0008103749598335767

# %% [markdown]
# ASAS 195113-2030.2

# %%
comparar_curvas(np.deg2rad(83.4),0.7211, 0.125, 0.093, 0.536,7.04335, '195113')
# Out:
# Mejor t0 seleccionado: 2000.85634
# Numero de puntos experimentales= 458
# Promedio de magnitudes en fase 0.25: 1.2356526407169708
# Promedio de magnitudes en fase 0.75: 1.2125352434890835
# Factor escalar = 1.2239667081497063
# Suma de errores cuadráticos normalizada: 0.0003554001582584531

# %% [markdown]
# Comparar Curvas de Luz con parámetros (i,q, p1, p2, L2/L1)

# %% [markdown]
# ASAS 203113+0513.2

# %%
comparar_curvas_pot(np.deg2rad(77.06),0.914,6.017 ,4.384,1.282, 0.52169, 203113)
# Out:
# Mejor t0 seleccionado: 4256.8389
# Numero de puntos experimentales= 401
# Promedio de magnitudes en fase 0.25: 3.28069740718842
# Promedio de magnitudes en fase 0.75: 3.2532130396261385
# Factor escalar = 3.2556557524367373
# Suma de errores cuadráticos normalizada: 0.010620726273643868

# %% [markdown]
# ASAS 011416+0426.4

# %%
comparar_curvas_pot(np.deg2rad(88.323), 0.808 ,9.763, 11.359 ,0.299, 2.478, '011416')
# Out:
# Mejor t0 seleccionado: 2990.61861
# Numero de puntos experimentales= 359
# Promedio de magnitudes en fase 0.25: 0.6033786654434051
# Promedio de magnitudes en fase 0.75: 0.5906236041829919
# Factor escalar = 0.5955084368705397
# Suma de errores cuadráticos normalizada: 0.0005770649601625911
